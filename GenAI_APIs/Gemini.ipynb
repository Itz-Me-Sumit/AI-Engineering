# %%
import os
import dotenv
import warnings
warnings.filterwarnings("ignore")

from google import generativeai as genai

genai.configure(
    api_key = os.getenv("GEMINI_API_KEY")
)

model = genai.GenerativeModel("gemini-3.6-flash")

prompt = "Give a user friendly Explaination of LLMs under 200 words"

response = model.generate_content(prompt)

print(f"User : {prompt}\n\nResponse : {response.text}")
# Out:
# User : Give a user friendly Explaination of LLMs under 200 words
# Response : Imagine the autocomplete on your phone, but powered by a supercomputer that has read almost the entire internet. That is a Large Language Model (LLM).
#
# LLMs are a type of artificial intelligence trained on massive amounts of text—books, articles, websites, and code. By analyzing all this data, they learn how human language works, including grammar, context, facts, and even tone.
#
# When you ask an LLM a question, it doesn't "think" like a human. Instead, it predicts the best and most helpful response, word by word, based on the patterns it learned during training.
#
# Because of this, LLMs are incredibly versatile. They can:
# * Write essays and emails
# * Summarize long documents
# * Translate languages
# * Help write computer code
# * Answer complex questions
#
# Think of an LLM as a super-powered digital assistant for language. However, because they rely on pattern recognition rather than real understanding, they aren't perfect—they can occasionally sound convincing while getting facts completely wrong. Always double-check important information!

# %%
print(f"User : {prompt}\n\nResponse : {response.text}")
# Out:
# User : Give a user friendly Explaination of LLMs under 200 words
#
# Response : Imagine the autocomplete on your phone, but powered by a supercomputer that has read almost the entire internet. That is a Large Language Model (LLM).
#
# LLMs are a type of artificial intelligence trained on massive amounts of text—books, articles, websites, and code. By analyzing all this data, they learn how human language works, including grammar, context, facts, and even tone.
#
# When you ask an LLM a question, it doesn't "think" like a human. Instead, it predicts the best and most helpful response, word by word, based on the patterns it learned during training.
#
# Because of this, LLMs are incredibly versatile. They can:
# * Write essays and emails
# * Summarize long documents
# * Translate languages
# * Help write computer code
# * Answer complex questions
#
# Think of an LLM as a super-powered digital assistant for language. However, because they rely on pattern recognition rather than real understanding, they aren't perfect—they can occasionally sound convincing while getting facts completely wrong. Always double-check important information!

# %%
response
# Out:
# response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "Imagine the autocomplete on your phone, but powered by a supercomputer that has read almost the entire internet. That is a Large Language Model (LLM).\n\nLLMs are a type of artificial intelligence trained on massive amounts of text\u2014books, articles, websites, and code. By analyzing all this data, they learn how human language works, including grammar, context, facts, and even tone.\n\nWhen you ask an LLM a question, it doesn't \"think\" like a human. Instead, it predicts the best and most helpful response, word by word, based on the patterns it learned during training.\n\nBecause of this, LLMs are incredibly versatile. They can:\n* Write essays and emails\n* Summarize long documents\n* Translate languages\n* Help write computer code\n* Answer complex questions\n\nThink of an LLM as a super-powered digital assistant for language. However, because they rely on pattern recognition rather than real understanding, they aren't perfect\u2014they can occasionally sound convincing while getting facts completely wrong. Always double-check important information!"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "index": 0
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 16,
#         "candidates_token_count": 219,
#         "total_token_count": 751
#       },
#       "model_version": "gemini-3.6-flash"
#     }),
# )

# %%
print(response.text)
# Out:
# Imagine the autocomplete on your phone, but powered by a supercomputer that has read almost the entire internet. That is a Large Language Model (LLM).
#
# LLMs are a type of artificial intelligence trained on massive amounts of text—books, articles, websites, and code. By analyzing all this data, they learn how human language works, including grammar, context, facts, and even tone.
#
# When you ask an LLM a question, it doesn't "think" like a human. Instead, it predicts the best and most helpful response, word by word, based on the patterns it learned during training.
#
# Because of this, LLMs are incredibly versatile. They can:
# * Write essays and emails
# * Summarize long documents
# * Translate languages
# * Help write computer code
# * Answer complex questions
#
# Think of an LLM as a super-powered digital assistant for language. However, because they rely on pattern recognition rather than real understanding, they aren't perfect—they can occasionally sound convincing while getting facts completely wrong. Always double-check important information!
