# %%
import warnings 
warnings.filterwarnings("ignore")

# %% [markdown]
# #### DuckDuckGo - for web search like google

# %%
from langchain_community.tools import DuckDuckGoSearchRun
search_tool = DuckDuckGoSearchRun()
result = search_tool.invoke("Political News")
for sentence in result.split("."):
    print(sentence.strip())
# Out:
# The Maine Republican is betting her record and local ties can withstand a polarized political climate
# 1 month ago - What began as an annual debate over noise pollution during Pune’s Ganesh Festival has grown into a political controversy, leaving the BJP caught between its festival-mandal base and growing public anger over DJs
# 8 hours ago - The DMK turned Vijay's Assembly provocation over MISA and the Sarkaria Commission into a full-blown political fight
# 1 week ago - The government is seeking to change the law on donations to UK political parties from British expats
# August 10, 2026 - Political News 2023: Get daily political news from India and the World with latest politics headlines, current affairs
# Also read latest news and reports on Tripura, Meghalaya and Nagaland Assembly elections 2023

# %% [markdown]
# #### ShellTool - to run commands into shell

# %%
from langchain_community.tools import ShellTool
shell_tool = ShellTool()
result = shell_tool.invoke("whoami")
print(result)
# Out:
# Executing command:
#  whoami
# sumit\sumit
